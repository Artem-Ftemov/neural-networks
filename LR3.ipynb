# %% [markdown]
# Ініціалізуємо підключення до google-диску, щоб отримати файл Housing.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Імпортуємо залежності

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Налаштовуємо seaborn

# %%
face_color = 'FFFFFF'
grid_color = ".10"
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("dark")
sns.set_style(rc={'axes.facecolor': face_color, 'grid.color': grid_color})

# %% [markdown]
# Зчитуємо дані з файлу Housing.csv у датафрейм

# %%
df = pd.read_csv('/content/drive/MyDrive/Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ---
# **Виводимо графіки з різними даними**
#
# ---

# %%
df['area'].hist(color = '#F07427', )
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['price'], color = 'cyan')

# %%
palette = ['orange', 'purple']
histplot_data = df[['bedrooms','bathrooms']]
sns.histplot(histplot_data, bins=10, multiple='dodge', palette=palette)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=df['price'],bins=10,color='cyan')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.scatterplot(data=df, x="area", y="price", color = 'purple')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.lineplot(data=df, y="area", x='price', color = 'purple')
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
